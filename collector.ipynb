# %%
from collect_precipitation_impact_cases_minimal_fixed import run_collection

countries = [
    # "Angola",
    # "Burundi",
    # "Benin",
    # "Brazil",
    # "Brunei",
    # "Central African Republic",
    # "Côte d’Ivoire",
    # "Cameroon",
    # "Democratic Republic of Congo",
    # "Republic of Congo",
    # "Colombia",
    # "Ecuador",
    # "Ethiopia",
    # "Gabon",
    # "Equatorial Guinea",
    # "Guyana",
    # "Indonesia",
    # "Kenya",
    # "Liberia",
    # "Sri Lanka",
    # "Malaysia",
    # "Nigeria",
    # "Peru",
    # "Papua New Guinea",
    # "Rwanda",
    "Somalia",
    "South Sudan",
    "Suriname",
    "Togo",
    "Tanzania",
    "Uganda",
    "Venezuela",
]

df = run_collection(
    countries_list=countries,
    target_per_country=50,
    batches=4,
    resume=True,
)

df.to_csv("outputs/full_precipitation_impact_cases_2024_2.csv", index=False)
df.head()
# Out:
# [country] Guyana
# [api] batch=1/4; current=0
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=245
# [api] batch=2/4; current=4
# [new] 19
# [saved] outputs/cases_deduped_2.csv | rows=245
# [api] batch=3/4; current=4
# [new] 26
# [saved] outputs/cases_deduped_2.csv | rows=248
# [api] batch=4/4; current=7
# [new] 22
# [saved] outputs/cases_deduped_2.csv | rows=248
#
# [country] Indonesia
# [api] batch=1/4; current=0
# [new] 12
# [saved] outputs/cases_deduped_2.csv | rows=260
# [api] batch=2/4; current=12
# [new] 25
# [saved] outputs/cases_deduped_2.csv | rows=273
# [api] batch=3/4; current=25
# [new] 16
# [saved] outputs/cases_deduped_2.csv | rows=273
# [api] batch=4/4; current=25
# [new] 23
# [saved] outputs/cases_deduped_2.csv | rows=273
#
# [country] Kenya
# [api] batch=1/4; current=0
# [new] 10
# [saved] outputs/cases_deduped_2.csv | rows=283
# [api] batch=2/4; current=10
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=287
# [api] batch=3/4; current=14
# [new] 15
# [saved] outputs/cases_deduped_2.csv | rows=292
# [api] batch=4/4; current=19
# [new] 17
# [saved] outputs/cases_deduped_2.csv | rows=303
#
# [country] Liberia
# [api] batch=1/4; current=0
# [new] 3
# [saved] outputs/cases_deduped_2.csv | rows=304
# [api] batch=2/4; current=1
# [new] 4
# [saved] outputs/cases_deduped_2.csv | rows=305
# [api] batch=3/4; current=2
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=307
# [api] batch=4/4; current=4
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=307
#
# [country] Sri Lanka
# [api] batch=1/4; current=0
# [new] 12
# [saved] outputs/cases_deduped_2.csv | rows=313
# [api] batch=2/4; current=6
# [new] 19
# [saved] outputs/cases_deduped_2.csv | rows=317
# [api] batch=3/4; current=10
# [new] 20
# [saved] outputs/cases_deduped_2.csv | rows=317
# [api] batch=4/4; current=10
# [new] 20
# [saved] outputs/cases_deduped_2.csv | rows=317
#
# [country] Malaysia
# [api] batch=1/4; current=0
# [new] 10
# [saved] outputs/cases_deduped_2.csv | rows=326
# [api] batch=2/4; current=9
# [new] 17
# [saved] outputs/cases_deduped_2.csv | rows=331
# [api] batch=3/4; current=14
# [new] 17
# [saved] outputs/cases_deduped_2.csv | rows=335
# [api] batch=4/4; current=18
# [new] 21
# [saved] outputs/cases_deduped_2.csv | rows=336
#
# [country] Nigeria
# [api] batch=1/4; current=26
# [new] 25
# [saved] outputs/cases_deduped_2.csv | rows=336
# [api] batch=2/4; current=26
# [new] 22
# [saved] outputs/cases_deduped_2.csv | rows=336
# [api] batch=3/4; current=26
# [new] 24
# [saved] outputs/cases_deduped_2.csv | rows=336
# [api] batch=4/4; current=26
# [new] 20
# [saved] outputs/cases_deduped_2.csv | rows=336
#
# [country] Peru
# [api] batch=1/4; current=0
# [new] 9
# [saved] outputs/cases_deduped_2.csv | rows=345
# [api] batch=2/4; current=9
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=350
# [api] batch=3/4; current=14
# [new] 9
# [saved] outputs/cases_deduped_2.csv | rows=350
# [api] batch=4/4; current=14
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=350
#
# [country] Papua New Guinea
# [api] batch=1/4; current=0
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=357
# [api] batch=2/4; current=7
# [new] 15
# [saved] outputs/cases_deduped_2.csv | rows=366
# [api] batch=3/4; current=16
# [new] 28
# [saved] outputs/cases_deduped_2.csv | rows=373
# [api] batch=4/4; current=23
# [new] 22
# [saved] outputs/cases_deduped_2.csv | rows=375
#
# [country] Rwanda
# [api] batch=1/4; current=0
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=381
# [api] batch=2/4; current=6
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=382
# [api] batch=3/4; current=7
# [new] 4
# [saved] outputs/cases_deduped_2.csv | rows=383
# [api] batch=4/4; current=8
# [retry] HTTP 429; sleep=60s
# [new] 5
# [saved] outputs/cases_deduped_2.csv | rows=384
#
# [country] Somalia
# [api] batch=1/4; current=0
# [new] 4
# [saved] outputs/cases_deduped_2.csv | rows=388
# [api] batch=2/4; current=4
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=391
# [api] batch=3/4; current=7
# [new] 6
# [saved] outputs/cases_deduped_2.csv | rows=391
# [api] batch=4/4; current=7
# [new] 8
# [saved] outputs/cases_deduped_2.csv | rows=391
#
# [country] South Sudan
# [api] batch=1/4; current=0
# [retry] HTTP 429; sleep=60s
# [new] 5
# [saved] outputs/cases_deduped_2.csv | rows=395
# [api] batch=2/4; current=4
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=397
# [api] batch=3/4; current=6
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=400
# [api] batch=4/4; current=9
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=400
#
# [country] Suriname
# [api] batch=1/4; current=0
# [new] 5
# [saved] outputs/cases_deduped_2.csv | rows=405
# [api] batch=2/4; current=5
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=407
# [api] batch=3/4; current=7
# [new] 8
# [saved] outputs/cases_deduped_2.csv | rows=409
# [api] batch=4/4; current=9
# [new] 7
# [saved] outputs/cases_deduped_2.csv | rows=411
#
# [country] Togo
# [api] batch=1/4; current=0
# [new] 3
# [saved] outputs/cases_deduped_2.csv | rows=414
# [api] batch=2/4; current=3
# [new] 4
# [saved] outputs/cases_deduped_2.csv | rows=416
# [api] batch=3/4; current=5
# [new] 13
# [saved] outputs/cases_deduped_2.csv | rows=417
# [api] batch=4/4; current=6
# [new] 15
# [saved] outputs/cases_deduped_2.csv | rows=417
#
# [country] Tanzania
# [api] batch=1/4; current=0
# [new] 12
# [saved] outputs/cases_deduped_2.csv | rows=421
# [api] batch=2/4; current=4
# [new] 17
# [saved] outputs/cases_deduped_2.csv | rows=421
# [api] batch=3/4; current=4
# [new] 17
# [saved] outputs/cases_deduped_2.csv | rows=421
# [api] batch=4/4; current=4
# [new] 30
# [saved] outputs/cases_deduped_2.csv | rows=423
#
# [country] Uganda
# [api] batch=1/4; current=12
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=426
# [api] batch=2/4; current=15
# [new] 14
# [saved] outputs/cases_deduped_2.csv | rows=427
# [api] batch=3/4; current=16
# [new] 20
# [saved] outputs/cases_deduped_2.csv | rows=430
# [api] batch=4/4; current=19
# [new] 16
# [saved] outputs/cases_deduped_2.csv | rows=430
#
# [country] Venezuela
# [api] batch=1/4; current=0
# [new] 8
# [saved] outputs/cases_deduped_2.csv | rows=438
# [api] batch=2/4; current=8
# [new] 10
# [saved] outputs/cases_deduped_2.csv | rows=445
# [api] batch=3/4; current=15
# [new] 12
# [saved] outputs/cases_deduped_2.csv | rows=450
# [api] batch=4/4; current=20
# [new] 15
# [saved] outputs/cases_deduped_2.csv | rows=450
# [saved] outputs/cases_deduped_2.csv | rows=450
#        event_id country                      where        when  \
# 0  ba12a837a03f  Angola              Viana, Luanda  2024-04-22
# 1  d6d8bad2e129  Angola   Porto Amboim, Cuanza-Sul  2024-04-07
# 2  8ffe7a750671  Angola  Cacula and Humpata, Huíla  2024-01-16
# 3  66c5d428967a  Angola          Cacolo, Lunda-Sul  2024-03-10
# 4  3cee2e9972b1  Angola            Luanda province  2024-02-14
#
#                                      what_happened  \
# 0               Sellers blamed bad roads and rain.
# 1  Flooded bridge forced EN100 circulation limits.
# 2        Farmers could not take produce to market.
# 3   Rain and bad roads delayed material transport.
# 4   Road degradation caused fruit losses en route.
#
#             precipitation_impact  \
# 0        market access disrupted
# 1                 bridge flooded
# 2  transport to market disrupted
# 3    materials transport delayed
# 4          goods in transit lost
#
#                                           source_url     source_domain  \
# 0  https://www.africa-press.net/angola/all-news/3...  africa-press.net
# 1  https://www.africa-press.net/angola/all-news/p...  africa-press.net
# 2  https://www.africa-press.net/angola/all-news/k...  africa-press.net
# 3  https://www.africa-press.net/angola/all-news/d...  africa-press.net
# 4  https://www.africa-press.net/angola/all-news/m...  africa-press.net
#
#            collected_at
# 0  2026-05-18T21:23:44Z
# 1  2026-05-18T21:23:44Z
# 2  2026-05-18T21:23:44Z
# 3  2026-05-18T21:23:44Z
# 4  2026-05-18T21:23:44Z
